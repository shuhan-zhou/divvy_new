# %% [markdown]
# Previously, we studied variation in number of divvy trips according to user charcteristics and time/season.
#
# But we may wonder: does the number of divvy stations also help/limit the number of trips?
#
# After all, if people do not even have access to divvy bikes, how can they become a user?
#
# In this notebook, we study the relationship between the number of trips and number of divvy stations.

# %% [markdown]
# ## Divvy Trips & Divvy Station

# %%
import requests, json
import pandas as pd
import datetime as dt
import matplotlib as plt
import geopandas as gpd
from shapely.geometry import Point


# %matplotlib inline

# %%
station = pd.read_csv("Divvy_Bicycle_Stations_-_All_-_Map.csv")

# %%
station.head()
# Out:
#     ID                Station Name                     Address  Total Docks  \
# 0   14         Morgan St & 18th St              962 W. 18th St           15
# 1   73    Jefferson St & Monroe St          207 S Jefferson St           19
# 2  622  California Ave & Cortez St  California Ave & Cortez St           15
# 3   59   Wabash Ave & Roosevelt Rd           1210 S Wabash Ave           23
# 4    6              Dusable Harbor              Dusable Harbor           39
#
#    Docks in Service      Status   Latitude  Longitude                 Location
# 0                15  In Service  41.858086 -87.651073  (41.858086, -87.651073)
# 1                19  In Service  41.880422 -87.642746  (41.880422, -87.642746)
# 2                15  In Service  41.900363 -87.696704  (41.900363, -87.696704)
# 3                23  In Service  41.867227 -87.625961  (41.867227, -87.625961)
# 4                38  In Service  41.885041 -87.612794  (41.885041, -87.612794)

# %% [markdown]
# The station data includes station ID, station name & address longitude and lattitude, the number of divvy bikes on dock. If we combine this dataset with the trip data, we can get account of how many trips are started/ended from a specific station, which station gets used the most often.
#
# Now lets do it

# %%
trips_2017_q1= pd.read_csv('/Users/shuhan_zhou/Documents/GitHub/divvy_new/Divvy_Trips_2017_Q1Q2/Divvy_Trips_2017_Q1.csv')
trips_2017_q2= pd.read_csv('/Users/shuhan_zhou/Documents/GitHub/divvy_new/Divvy_Trips_2017_Q1Q2/Divvy_Trips_2017_Q2.csv')

trips_2017 = trips_2017_q1.append(trips_2017_q2)

# %% [markdown]
# ### Stations where Trips Got Started

# %% [markdown]
# we attemp the merge using station ID as the index to merge on

# %%
trips_2017['from_station_id'] = pd.to_numeric(trips_2017['from_station_id'], errors='coerce')

trips_2017_start = trips_2017.set_index('from_station_id')
trips_2017_start.index.names = ['ID']

# %%
trips_2017_start
# Out:
#       trip_id          start_time            end_time  bikeid  tripduration  \
# ID
# 66   13518905  3/31/2017 23:59:07   4/1/2017 00:13:24    5292           857
# 199  13518904  3/31/2017 23:56:25   4/1/2017 00:00:21    4408           236
# 520  13518903  3/31/2017 23:55:33   4/1/2017 00:01:21     696           348
# 110  13518902  3/31/2017 23:54:46  3/31/2017 23:59:34    4915           288
# 327  13518901  3/31/2017 23:53:33   4/1/2017 00:00:28    4247           415
# 143  13518900  3/31/2017 23:51:17  3/31/2017 23:55:19    3536           242
# 81   13518899  3/31/2017 23:51:16  3/31/2017 23:57:17    5111           361
# 56   13518898  3/31/2017 23:50:26  3/31/2017 23:56:20    1579           354
# 210  13518897  3/31/2017 23:50:25  3/31/2017 23:55:24    3914           299
# 117  13518896  3/31/2017 23:49:58   4/1/2017 00:09:31    5455          1173
# 117  13518895  3/31/2017 23:49:51   4/1/2017 00:09:31    4282          1180
# 227  13518894  3/31/2017 23:49:34  3/31/2017 23:57:58    4768           504
# 520              Clark St & Lunt Ave  Subscriber  Female     1979.0
# 110             McClurg Ct & Erie St  Subscriber    Male     1985.0
# 327    Halsted St & Blackhawk St (*)  Subscriber  Female     1989.0
# 143            Wells St & Concord Ln  Subscriber    Male     1988.0
# 81              Federal St & Polk St  Subscriber    Male     1987.0
# 56           Clinton St & Madison St  Subscriber    Male     1981.0
# 210           Damen Ave & Pierce Ave  Subscriber    Male     1992.0
# 117         Noble St & Milwaukee Ave  Subscriber    Male     1989.0
# 117         Noble St & Milwaukee Ave  Subscriber    Male     1989.0
# 227          Broadway & Cornelia Ave  Subscriber    Male     1988.0
# 199         McClurg Ct & Illinois St  Subscriber  Female     1990.0
# 59               Buckingham Fountain  Subscriber    Male     1984.0
# 67      Ashland Ave & Wellington Ave  Subscriber    Male     1982.0
# 333        Ashland Ave & Division St  Subscriber    Male     1992.0
# 77                Wells St & Polk St  Subscriber  Female     1979.0
# 90               Buckingham Fountain  Subscriber    Male     1980.0
# 38          Fairbanks Ct & Grand Ave  Subscriber    Male     1990.0
# 91                 Wells St & Elm St  Subscriber    Male     1970.0
# 69         Damen Ave & Charleston St  Subscriber    Male     1986.0
# 66             Franklin St & Lake St  Subscriber    Male     1984.0
# 26              Halsted St & 18th St  Subscriber    Male     1984.0
# 75         Michigan Ave & Madison St  Subscriber    Male     1982.0
# 230        Clark St & Wrightwood Ave  Subscriber    Male     1987.0
# 289           Clark St & Lincoln Ave  Subscriber    Male     1976.0
# 291           Clark St & Chicago Ave  Subscriber  Female     1987.0
# 112     Stetson Ave & South Water St  Subscriber  Female     1987.0
# 383           Clinton St & Tilden St  Subscriber    Male     1986.0
# 53    Sheffield Ave & Wellington Ave  Subscriber    Male     1992.0
# ..                               ...         ...     ...        ...
# 123        Ashland Ave & Division St  Subscriber    Male     1986.0
# 47              Clinton St & Lake St  Subscriber    Male     1990.0
# 87    Southport Ave & Wrightwood Ave  Subscriber    Male     1995.0
# 131     Ravenswood Ave & Berteau Ave  Subscriber    Male     1990.0
# 240  Pine Grove Ave & Irving Park Rd  Subscriber    Male     1990.0
# 22              Halsted St & Polk St  Subscriber  Female     1997.0
# 228          Clark St & Montrose Ave  Subscriber    Male     1981.0
# 148            Calumet Ave & 33rd St  Subscriber    Male     1991.0
# 148            Calumet Ave & 33rd St  Subscriber    Male     1989.0
# 198     Michigan Ave & Washington St  Subscriber    Male     1985.0
# 332        Southport Ave & Roscoe St  Subscriber    Male     1984.0
# 337           St. Clair St & Erie St  Subscriber    Male     1980.0
# 19              Racine Ave & 18th St  Subscriber    Male     1991.0
# 197        Wabash Ave & Roosevelt Rd  Subscriber    Male     1985.0
# 31            Clark St & Chicago Ave  Subscriber    Male     1980.0
# 96             Dearborn St & Erie St  Subscriber    Male     1987.0
# 77          Loomis St & Lexington St  Subscriber    Male     1993.0
# 130          Western Ave & Walton St  Subscriber    Male     1995.0
# 282             Halsted St & 18th St  Subscriber    Male     1988.0
# 39      Clinton St & Washington Blvd  Subscriber    Male     1986.0
# 47         Desplaines St & Kinzie St  Subscriber    Male     1975.0
# 69        Ashland Ave & Blackhawk St  Subscriber    Male     1992.0
# 581              Commercial Ave & 83rd St            398
# 581              Commercial Ave & 83rd St            355
# 581              Commercial Ave & 83rd St             12
# 581              Commercial Ave & 83rd St             12
# 581              Commercial Ave & 83rd St            580
# 581              Commercial Ave & 83rd St            581
# 581              Commercial Ave & 83rd St            398
# 581              Commercial Ave & 83rd St            398
#
#                     to_station_name    usertype  gender  birthyear
# 2             Wabash Ave & Adams St    Customer     NaN        NaN
# 2             Wabash Ave & Adams St    Customer     NaN        NaN
# 2             Wabash Ave & Adams St    Customer     NaN        NaN
# 2             Wabash Ave & Adams St    Customer     NaN        NaN
# 2               Buckingham Fountain    Customer     NaN        NaN
# 2               Buckingham Fountain    Customer     NaN        NaN
# 2         Lake Shore Dr & Monroe St    Customer     NaN        NaN
# 2         Lake Shore Dr & Monroe St    Customer     NaN        NaN
# 2                   Millennium Park  Subscriber  Female     1975.0
# 2           Franklin St & Monroe St  Subscriber    Male     1969.0
# 2            Michigan Ave & Lake St  Subscriber    Male     1973.0
# 2         Michigan Ave & Madison St  Subscriber  Female     1964.0
# 2           Streeter Dr & Grand Ave  Subscriber  Female     1975.0
# 2             Canal St & Madison St  Subscriber    Male     1985.0
# 2                   Millennium Park    Customer     NaN        NaN
# 2                   Millennium Park    Customer     NaN        NaN
# 2                   Millennium Park    Customer     NaN        NaN
# 2                   Millennium Park    Customer     NaN        NaN
# 2                   Millennium Park    Customer     NaN        NaN
# 2                   Millennium Park  Subscriber    Male     1990.0
# 2      Financial Pl & Congress Pkwy  Subscriber    Male     1979.0
# 2                    Burnham Harbor    Customer     NaN        NaN
# 2                    Burnham Harbor    Customer     NaN        NaN
# 2      Michigan Ave & Washington St  Subscriber    Male     1959.0
# 2           Franklin St & Monroe St  Subscriber    Male     1969.0
# 2         Michigan Ave & Madison St  Subscriber  Female     1971.0
# 2           Lake Shore Dr & Ohio St  Subscriber    Male     1985.0
# 2       Field Blvd & South Water St  Subscriber  Female     1960.0
# 2            Dearborn St & Adams St  Subscriber    Male     1993.0
# 2           Streeter Dr & Grand Ave  Subscriber  Female     1989.0
# ..                              ...         ...     ...        ...
# 577  Museum of Science and Industry  Subscriber    Male     1966.0
# 577          Jeffery Blvd & 76th St  Subscriber    Male     1963.0
# 577      Stony Island Ave & 75th St  Subscriber    Male     1963.0
# 577      Stony Island Ave & 75th St  Subscriber    Male     1963.0
# 577     Cottage Grove Ave & 78th St  Subscriber    Male     1986.0
# 578           Bennett Ave & 79th St  Subscriber    Male     1963.0
# 578           Bennett Ave & 79th St  Subscriber    Male     1963.0
# 578           Bennett Ave & 79th St  Subscriber    Male     1963.0
# 579              State St & 35th St    Customer     NaN        NaN
# 579          Phillips Ave & 79th St    Customer     NaN        NaN
# 579                   Rainbow Beach  Subscriber    Male     1997.0
# 579        Commercial Ave & 83rd St  Subscriber    Male     1997.0
# 579      Saginaw Ave & Exchange Ave    Customer     NaN        NaN
# 580                   Rainbow Beach  Subscriber    Male     1987.0
# 580          Jeffery Blvd & 71st St    Customer     NaN        NaN
# 580        Commercial Ave & 83rd St    Customer     NaN        NaN
# 580        South Shore Dr & 71st St    Customer     NaN        NaN
# 580          Jeffery Blvd & 71st St    Customer     NaN        NaN
# 580                   63rd St Beach    Customer     NaN        NaN
# 580          Exchange Ave & 79th St    Customer     NaN        NaN
# 580        South Shore Dr & 71st St  Subscriber    Male     1997.0
# 581      Saginaw Ave & Exchange Ave  Subscriber  Female     1972.0
# 581                   Rainbow Beach  Subscriber    Male     1983.0
# 581        South Shore Dr & 67th St  Subscriber    Male     1997.0
# 581        South Shore Dr & 71st St    Customer     NaN        NaN
# 581        South Shore Dr & 71st St  Subscriber    Male     1979.0
# 581          Exchange Ave & 79th St  Subscriber    Male     1997.0
# 581        Commercial Ave & 83rd St  Subscriber    Male     1997.0
# 581                   Rainbow Beach    Customer     NaN        NaN
# 581                   Rainbow Beach    Customer     NaN        NaN
#
# [1533201 rows x 20 columns]

# %% [markdown]
# However, we notice there is a significant issue we forget: the station ID from the trip data and from the station data may not be matchable, which is to say the same ID can totally represent different stations since the data source is different!
#
# For example, station ID 622, represents station at California Ave and Cortez St in the station dataset.
#
# But it refers to the station at Buckingham Foundation in the trip dataset!
#
# These two locations are completely different and very far from each other!!!
#
# Therefore now we try the second best approach: using trips data alone to compute the trips taken from each station and only use the geographic information from the station data for the mapping

# %%
start = trips_2017['from_station_name'].value_counts().reset_index()
start.columns = ['from_station_name', 'start_count']

# %%
start.head()
# Out:
#               from_station_name  start_count
# 0       Streeter Dr & Grand Ave        36686
# 1  Clinton St & Washington Blvd        22429
# 2     Lake Shore Dr & Monroe St        21822
# 3       Clinton St & Madison St        19098
# 4           Canal St & Adams St        18105

# %% [markdown]
# The most popular stations to start trips with:
#
# Streeter Dr & Grand Ave                36686;
#
# Clinton St & Washington Blvd           22429;
#
# Lake Shore Dr & Monroe St              21822;
#
# Clinton St & Madison St                19098;
#
# Canal St & Adams St                    18105
#
#
# What if we want to know whether a lot of trip END at these stations too ?
#
# We repeat the same exercise for trip ending stations

# %%
end = trips_2017['to_station_name'].value_counts().reset_index()
end.columns = ['to_station_name', 'end_count']

# %%
end.head()
# Out:
#                 to_station_name  end_count
# 0       Streeter Dr & Grand Ave      39537
# 1  Clinton St & Washington Blvd      21113
# 2       Clinton St & Madison St      20969
# 3     Lake Shore Dr & Monroe St      20652
# 4    Lake Shore Dr & North Blvd      19734

# %% [markdown]
# Four of the top ending trip locations are included in the top starting trip locations!

# %% [markdown]
# So is there a statistical relationship between number of bikes on doc and number of start trips and end trips?

# %%
station = pd.read_csv("Divvy_Bicycle_Stations_-_All_-_Map.csv").set_index('Station Name')
station.dropna(inplace = True)

# %%
start = start.set_index('from_station_name')
end = end.set_index('to_station_name')
join = start.join(end)

# %%
join.head()
# Out:
#                               start_count  end_count
# from_station_name
# Streeter Dr & Grand Ave             36686    39537.0
# Clinton St & Washington Blvd        22429    21113.0
# Lake Shore Dr & Monroe St           21822    20652.0
# Clinton St & Madison St             19098    20969.0
# Canal St & Adams St                 18105    17351.0

# %%
join_station = station.join(join)
join_station.head()
# Out:
#                              ID                     Address  Total Docks  \
# Station Name
# Morgan St & 18th St          14              962 W. 18th St           15
# Jefferson St & Monroe St     73          207 S Jefferson St           19
# California Ave & Cortez St  622  California Ave & Cortez St           15
# Wabash Ave & Roosevelt Rd    59           1210 S Wabash Ave           23
# Dusable Harbor                6              Dusable Harbor           39
#
#                             Docks in Service      Status   Latitude  \
# Station Name
# Morgan St & 18th St                       15  In Service  41.858086
# Jefferson St & Monroe St                  19  In Service  41.880422
# California Ave & Cortez St                15  In Service  41.900363
# Wabash Ave & Roosevelt Rd                 23  In Service  41.867227
# Dusable Harbor                            38  In Service  41.885041
#
#                             Longitude                 Location  start_count  \
# Station Name
# Morgan St & 18th St        -87.651073  (41.858086, -87.651073)       1548.0
# Jefferson St & Monroe St   -87.642746  (41.880422, -87.642746)       4464.0
# California Ave & Cortez St -87.696704  (41.900363, -87.696704)        582.0
# Wabash Ave & Roosevelt Rd  -87.625961  (41.867227, -87.625961)       9243.0
# Dusable Harbor             -87.612794  (41.885041, -87.612794)       9171.0
#
#                             end_count
# Station Name
# Morgan St & 18th St            1668.0
# Jefferson St & Monroe St       4079.0
# California Ave & Cortez St      615.0
# Wabash Ave & Roosevelt Rd      9858.0
# Dusable Harbor                 7942.0

# %%
from scipy import stats
from statsmodels import api as sm
import statsmodels.formula.api as smf
import statsmodels.regression.mixed_linear_model as sm_mlm

from time import sleep

# %% [markdown]
# Is divvy bike's manager a smart manager? is he putting more bikes to places where there is high demand?
#
# we test this using a simple ols model using both trips starting from and ended in that station to represent demand

# %%
ols_1 = smf.ols(formula = "N ~ s + e ",
              data = join_station.rename(columns = {"Total Docks" : "N", 
                                          "start_count"  : "s",
                                         "end_count": "e"}))
model_1 = ols_1.fit()
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      N   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     378.5
# Date:                Fri, 01 Dec 2017   Prob (F-statistic):          2.52e-105
# Time:                        16:46:21   Log-Likelihood:                -1653.2
# No. Observations:                 573   AIC:                             3312.
# Df Residuals:                     570   BIC:                             3325.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8918      0.225     61.716      0.000      13.450      14.334
# s              0.0041      0.000      8.543      0.000       0.003       0.005
# e             -0.0027      0.000     -5.749      0.000      -0.004      -0.002
# ==============================================================================
# Omnibus:                      253.842   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2049.472
# Skew:                           1.760   Prob(JB):                         0.00
# Kurtosis:                      11.571   Cond. No.                     7.92e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.92e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# the following code is simply for storing the output in image file
import matplotlib.pyplot as plt
plt.text(0.01, 0.05, str(model_1.summary()), {'fontsize': 15}, fontproperties = 'monospace') 
plt.axis('off')
plt.tight_layout()
plt.savefig('trip_station_ols.png')

# %% [markdown]
# The results look very good to me! When 1000 more trips are started from a station, they put one more bike in supply. wHEN 1000 more trips are ended there, put 2 fewer bikes there.

# %% [markdown]
# Conversely, is user behavior responding to divvy's investment?
#
# We answer this question by ploting the relationship between number of trip start with total docks in service at each station

# %%
ax = sns.regplot(x = "Docks in Service", y = "start_count", data = join_station, scatter_kws = {"alpha" : 0.1})

fig = ax.get_figure()
fig.savefig("trip_dock_in_service.png")

# %% [markdown]
# it does not really make sense to plot number of trips ending at station with number of bikes at that station.
#
# because when people end their trips, they either get to their destination or get tired from riding bike.
#
# I would imagine very few people are being altruistic in the sense that they return their bikes so that other people can use.
#
# Hence, we will skip ploting number of trips ended with number of bikes
